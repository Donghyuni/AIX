# %% [markdown]
# 제약 사항
# *   제공한 라이브러리 사용
# *   주석으로 코드 설명
#
# 참조 페이지
#
# * https://docs.opencv.org/4.x/d4/dc6/tutorial_py_template_matching.html
#
# * https://matplotlib.org/stable/tutorials/introductory/images.html
#
# * https://docs.opencv.org/4.x/dc/dc3/tutorial_py_matcher.html
#
# * https://docs.opencv.org/4.x/d4/d86/group__imgproc__filter.html
#
# * https://docs.opencv.org/4.x/dd/d1a/group__imgproc__feature.html#gac1fc3598018010880e370e2f709b4345
#
# * https://docs.opencv.org/3.4/dd/d53/tutorial_py_depthmap.html

# %% [markdown]
# 사진 출처
#
# * https://www.youtube.com/watch?v=xRiPFfDal14

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ## 1) 제공된 사진 2장을 불러오고 시각화하기

# %%
face_img = cv2.imread('/content/얼굴사진.png')
eye_img = cv2.imread('/content/눈사진.png')

# write your code here 

plt.show()

# %% [markdown]
# ## 2) 제공한 눈 사진을 template 삼아 얼굴사진에서 눈 좌표(top_left) 출력하기

# %%
# write your code here

print("왼쪽 눈 위치: ", point_left)
print("오른쪽 눈 위치: ", point_right)
# Out:
# 눈 위치:  (211, 318)
# 눈 위치:  (407, 315)

# %% [markdown]
# ## 3) 제공된 얼굴사진에 눈 위치 사각형으로 표시하기(2개 전부)

# %%
# write your code here

plt.show()

# %% [markdown]
# ## 4) SIFT 서술자 추출기 생성, 각 사진에 대해 키 포인트와 서술자 추출

# %%
image_1 = cv2.imread('./3.png')
image_2 = cv2.imread('./4.png')
image_1 = cv2.cvtColor(image_1, cv2.COLOR_BGR2RGB)
image_2 = cv2.cvtColor(image_2, cv2.COLOR_BGR2RGB)
gray_1 = cv2.cvtColor(image_1, cv2.COLOR_BGR2GRAY)
gray_2 = cv2.cvtColor(image_2, cv2.COLOR_BGR2GRAY)

# %%
# SIFT 서술자 추출기 생성 
detector = # write your code


# 각 영상에 대해 키 포인트와 서술자 추출 
key_point1, desc1 = # write your code
key_point2, desc2 = # write your code

# %% [markdown]
# ## 5) BFMatcher 생성, Hamming 거리 상호체크 후 매칭 계산

# %%
# BFMatcher 생성, Hamming 거리, 상호 체크 
matcher = # write your code


# 매칭 계산 
matches = # write your code

# %% [markdown]
# ## 6) 매칭결과 그리기

# %%
plt.figure(figsize=(18,18))
plt.imshow(res)
plt.show()

# %% [markdown]
# ## 7) mean filter와 gaussian filter 적용하기

# %% [markdown]
# ### 파일 불러오기

# %%
img = cv2.imread('./얼굴사진.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()

# %% [markdown]
# ### gaussian filter 적용하기

# %%
noise_img = img.copy()
noise_img = np.clip((img / 255 + np.random.normal(scale=0.1, size=img.shape)) * 255, 0, 255).astype('uint8')
# write your code
filtered_img = 
#

plt.figure(figsize=(12,12))
plt.subplot(1,3,1)
plt.title('original image')
plt.imshow(img)
plt.subplot(1,3,2)
plt.title('image with noise')
plt.imshow(noise_img)
plt.subplot(1,3,3)
plt.title('filtered image')
plt.imshow(filtered_img)
plt.show()

# %% [markdown]
# ### median filter 적용하기

# %%
np.random.seed(42)
noise_img2 = img.copy()
N = 100000
x = np.random.randint(img.shape[0], size=N)
y = np.random.randint(img.shape[1], size=N)
noise_img2[x, y] = 0
# write your code
filtered_img2 = 
#

plt.figure(figsize=(12,12))
plt.subplot(1,3,1)
plt.title('original image')
plt.imshow(img)
plt.subplot(1,3,2)
plt.title('image with noise')
plt.imshow(noise_img2)
plt.subplot(1,3,3)
plt.title('filtered image')
plt.imshow(filtered_img2)
plt.show()

# %% [markdown]
# ## 8) Sobel filtering

# %%
img = cv2.imread('./얼굴사진.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# write your code
sobel_img = 
#

plt.imshow(sobel_img, cmap='gray')
plt.show()

# %% [markdown]
# ## 9) feature extracting(cornerharris)

# %%
img = cv2.imread('./feature_extracting.jpeg')
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray_img = np.float32(gray_img)

# write your code


plt.imshow(img)
plt.show()

# %% [markdown]
# ## 10) Depth Map from Stereo Images

# %%
imgL = cv2.imread('DM_left_image.png', cv2.IMREAD_GRAYSCALE)
imgR = cv2.imread('DM_right_image.png', cv2.IMREAD_GRAYSCALE)

# write your code

plt.show()
